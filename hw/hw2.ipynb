# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("hw2-data.txt", sep=" ", names=["height", "weight", "size"])
df
# Out:
#     height  weight size
# 0      158      58    M
# 1      158      59    M
# 2      158      63    M
# 3      160      59    M
# 4      160      60    M
# 5      163      60    M
# 6      163      61    M
# 7      160      64    L
# 8      163      64    L
# 9      165      61    L
# 10     165      62    L
# 11     165      65    L
# 12     168      62    L
# 13     168      63    L
# 14     168      66    L
# 15     170      63    L
# 16     170      64    L
# 17     170      68    L

# %%
sns.pairplot(df, hue='size')

# %%
distance = ((df["height"]-161)**2 + (df["weight"]-61)**2)**0.5
df_2 = df.copy().assign(distance=distance)
df_2
# df_2.sort_values("distance")
# Out:
#     height  weight size   distance
# 0      158      58    M   4.242641
# 1      158      59    M   3.605551
# 2      158      63    M   3.605551
# 3      160      59    M   2.236068
# 4      160      60    M   1.414214
# 5      163      60    M   2.236068
# 6      163      61    M   2.000000
# 7      160      64    L   3.162278
# 8      163      64    L   3.605551
# 9      165      61    L   4.000000
# 10     165      62    L   4.123106
# 11     165      65    L   5.656854
# 12     168      62    L   7.071068
# 13     168      63    L   7.280110
# 14     168      66    L   8.602325
# 15     170      63    L   9.219544
# 16     170      64    L   9.486833
# 17     170      68    L  11.401754

# %%
df_2.nsmallest(5, "distance")
# Out:
#    height  weight size  distance
# 4     160      60    M  1.414214
# 6     163      61    M  2.000000
# 3     160      59    M  2.236068
# 5     163      60    M  2.236068
# 7     160      64    L  3.162278
